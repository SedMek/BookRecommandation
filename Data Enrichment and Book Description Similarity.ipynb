# %% [markdown]
# <div class="alert alert-warning">
# <div class="label label-warning">NOTICE:</div><br>
# <li>Chrome driver is REQUIRED: It is used by Selenium to manipulate an internet navigator using Python code. This method is used to simulate a human use of the navigator, so it doesn't get blocked by websites (Amazon for example).</li>
# </div>

# %%
CHROME_PATH = "C:/Users/Seddik's PC/Desktop/Cours/Fun/Selenium/chromedriver.exe"

# %% [markdown]
# ## <a id='I'></a><h2 style="text-align=center; font-size=220">  <span class="label label-info" style="text-align=center;"> I. Searching for Name,	Category,	Author,	Language,	Pages,	and Dimensions information</span>  </h2>

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success"> Importing Libraries</span></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from tqdm import tqdm
import re # Regular expressions

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success"> Defining Base url</span></div>

# %%
BASE_URL = "https://www.amazon.fr/dp/"

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success">Reading the first 10 rows (for demonstration purposes)</span></div>

# %%
books = pd.read_csv("./Data/BX-Books.csv", nrows=100, sep=";",usecols=["ISBN","Year-Of-Publication"])
books.head()
# Out:
#         ISBN  Year-Of-Publication
# 0  195153448                 2002
# 1    2005018                 2001
# 2   60973129                 1991
# 3  374157065                 1999
# 4  393045218                 1999

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success">Creating columns for the features that we are going to fill</span></div>

# %%
books['Name'] = np.nan
books['Category'] = np.nan
books['Author'] = np.nan
books['Language'] = np.nan
books['Pages'] = np.nan
books['Dimensions'] = np.nan
books = books.set_index('ISBN')
books.head()
# Out:
#            Year-Of-Publication  Name  Category  Author  Language  Pages  \
# ISBN
# 195153448                 2002   NaN       NaN     NaN       NaN    NaN
# 2005018                   2001   NaN       NaN     NaN       NaN    NaN
# 60973129                  1991   NaN       NaN     NaN       NaN    NaN
# 374157065                 1999   NaN       NaN     NaN       NaN    NaN
# 393045218                 1999   NaN       NaN     NaN       NaN    NaN
#
#            Dimensions
# ISBN
# 195153448         NaN
# 2005018           NaN
# 60973129          NaN
# 374157065         NaN
# 393045218         NaN

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success">Defining XPaths that we are going to use to look for the information</span></div>

# %%
XPATH_NAME = '//h1[@id="title"]/span[@id="productTitle"]'
XPATH_CATEGORY = '//a[@class="a-link-normal a-color-tertiary"]'
XPATH_AUTHOR = '//span[@class="author notFaded"]'
# XPATH_AUTHOR = '//span[@class="author notFaded"]/a[@class="a-link-normal"]'
XPATH_PAGES = '//td[@class="bucket"]/div/ul/li[contains(text(),"pages")]'
XPATH_LANGUAGE = '//td[@class="bucket"]/div/ul/li[contains(b,"Langue")]'
XPATH_DIMENSIONS = '//td[@class="bucket"]/div/ul/li[contains(b,"Dimensions")]'

# %%
def get_info(driver, *url):
    """
    extracts the features from a given book amazon url

    driver: the Selenium web navigator driver
    url: the book amazon url
    """
    if url:
        driver.get(url[0])
    else:
        pass
    name, categories, authors, language, pages, dimensions = (np.nan for i in range(6))
    try:
        name = driver.find_element_by_xpath(XPATH_NAME).text
    except:
        pass
    try:
        pages = driver.find_element_by_xpath(XPATH_PAGES).text
        pages = re.findall('\d+',pages)[0]
    except:
        pass            
    try:
        language = driver.find_element_by_xpath(XPATH_LANGUAGE).text
        language = language.split(':')[-1].strip()
    except:
        pass            
    try:
        dimensions = driver.find_element_by_xpath(XPATH_DIMENSIONS).text
        dimensions = dimensions.split(':')[-1].strip()
    except:
        pass            
    try:
        categories =driver.find_elements_by_xpath(XPATH_CATEGORY)
        categories = ' > '.join([elem.text for elem in categories])
        if len(categories) == 0:
            categories = np.nan
    except:
        pass            
    try:
        authors = driver.find_elements_by_xpath(XPATH_AUTHOR)
        authors = ' , '.join([re.findall('^[^(]+',author.text)[0].strip() for author in authors])
        if len(authors) == 0:
            authors = np.nan
    except:
        pass

    return name, categories, authors, language, pages, dimensions

# %%
def double_check(isbn,driver):
    """
    Checks if all the features are extracted. If not, it looks for other links to gather the remaining feature information
    
    isbn: the books id
    driver: Selenium web navigator driver
    """
    retry_counter = 1
    while books.loc[isbn].isnull().values.any():
        try:
            elem = driver.find_element_by_id("a-autoid-{}-announce".format(retry_counter)) # to check for other links to the product
            if elem.get_attribute('href'):
                if elem.get_attribute('href').find('/dp/') > -1:
                    
                    elem.click()
                    
                    parsed = get_info(driver)
                    if (books.loc[isbn,'Category'] is np.nan) and not re.search('(audio)|(audible)|(ebook)|(kindle)',str(parsed[1]).lower()):
                        books.loc[isbn,'Category'] = parsed[1]
                    if books.loc[isbn,'Author'] is np.nan:
                        books.loc[isbn,'Author'] = parsed[2]
                    if books.loc[isbn,'Language'] is np.nan:
                        books.loc[isbn,'Language'] = parsed[3]
                    if books.loc[isbn,'Pages'] is np.nan:
                        books.loc[isbn,'Pages'] = parsed[4]
                    if books.loc[isbn,'Dimensions'] is np.nan:
                        books.loc[isbn,'Dimensions'] = parsed[5]
                    
                    driver.back()
        except:
            print('finished all available links ({}, {})'.format(retry_counter, isbn))
            break # if the link doesn't exist, break

        retry_counter += 1

# %% [markdown]
# ## <a id='I'></a><h2 style="text-align=center; font-size=220">  <span class="label label-info" style="text-align=center;"> I. Searching for Name,	Category,	Author,	Language,	Pages,	and Dimensions information</span>  </h2>

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success">Scrapping Amazon with double check: if we don't find all the information in the first page, look for it in another page</span></div>

# %%
if __name__ == '__main__':

    # instantiate a chrome options object so you can set the size and headless preference
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--window-size=1920x1080")

    # Chrome without pictures for reduced loading time
    chrome_options = webdriver.ChromeOptions()
    prefs = {"profile.managed_default_content_settings.images": 2}
    chrome_options.add_experimental_option("prefs", prefs)

    driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=CHROME_PATH)

    driver.maximize_window()
    for isbn in tqdm(books.index):
        books.loc[isbn,['Name', 'Category', 'Author', 'Language','Pages', 'Dimensions']] = get_info(driver, BASE_URL+isbn)
        double_check(isbn, driver)
    driver.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: use options instead of chrome_options
#   del sys.path[0]
#  32%|█████████████████████████▉                                                       | 32/100 [02:31<05:08,  4.54s/it]
# finished all available links (3, 3404921038)
#  33%|██████████████████████████▋                                                      | 33/100 [02:37<05:46,  5.17s/it]
# finished all available links (3, 3442353866)
#  35%|████████████████████████████▎                                                    | 35/100 [02:42<04:06,  3.79s/it]
# finished all available links (4, 3442446937)
#  53%|██████████████████████████████████████████▉                                      | 53/100 [05:13<03:31,  4.51s/it]
# finished all available links (7, 0060914068)
#  55%|████████████████████████████████████████████▌                                    | 55/100 [05:43<08:01, 10.71s/it]
# finished all available links (1, 0245542957)
#  58%|██████████████████████████████████████████████▉                                  | 58/100 [05:54<04:15,  6.09s/it]
# finished all available links (1, 0961769947)
#  79%|███████████████████████████████████████████████████████████████▉                 | 79/100 [08:25<03:05,  8.84s/it]
# finished all available links (5, 1569871213)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [10:08<00:00,  4.81s/it]

# %%
books
# Out:
#             Year-Of-Publication  \
# ISBN
# 0195153448                 2002
# 0002005018                 2001
# 0060973129                 1991
# 0374157065                 1999
# 0393045218                 1999
# 0399135782                 1991
# 0425176428                 2000
# 0671870432                 1993
# 0679425608                 1996
# 074322678X                 2002
# 0771074670                 1988
# 080652121X                 2000
# 0887841740                 2004
# 1552041778                 1999
# 1558746218                 1998
# 1567407781                 1998
# 1575663937                 1999
# 1881320189                 1994
# 0440234743                 1999
# 0452264464                 1994
# 0609804618                 1999
# 1841721522                 2001
# 1879384493                 2003
# 0061076031                 2000
# 0439095026                 1999
# 0689821166                 1998
# 0971880107                 2004
# 0345402871                 1997
# 0345417623                 2000
# 0684823802                 1996
# ...                         ...
# 1853260053                 1997
# 1414035004                 2003
# 0060938412                 2003
# 0140067477                 1983
# 0345465083                 2003
# 0451625889                 1952
# 1558531025                 1991
# 0441783589                 1987
# 0394895894                 1988
# 1569871213                 1995
# 0375410538                 2000
# 0966986105                 1999
# 087113375X                 1990
# 0340767936                 2000
# 0743403843                 2002
# 0060930365                 1999
# 0060177586                 1994
# 0071416331                 2003
# 0375509038                 2003
# 0553062042                 1981
# 0316769487                 1991
# 8445071408                 2001
# 8445071769                 2001
# 8445071777                 2001
# 0679429220                 1994
# 0671867156                 1998
# 0312252617                 2001
# 0312261594                 2001
# 0316748641                 2002
# 0316973742                 2002
#
#                                                          Name  \
# ISBN
# 0195153448                                Classical Mythology
# 0002005018                              Clara Callan: A novel
# 0060973129                               Decision in Normandy
# 0374157065  Flu: The Story of the Great Influenza Pandemic...
# 0393045218                             The Mummies of Urumchi
# 0399135782                             The Kitchen God's Wife
# 0425176428  What If?: The World's Foremost Historians Imag...
# 0671870432                                    Pleading Guilty
# 0679425608  Under the Black Flag: The Romance and the Real...
# 074322678X            Where You'll Find Me: And Other Stories
# 0771074670                        Nights Below Station Street
# 080652121X                     Hitler's Secret Bankers - Revi
# 0887841740                                 The Middle Stories
# 1552041778                                           Jane Doe
# 1558746218  A Second Chicken Soup for the Woman's Soul: 10...
# 1567407781                                    The Witchfinder
# 1575663937                              More Cunning Than Man
# 1881320189                      Goodbye to the Buttermilk Sky
# 0440234743                                      The Testament
# 0452264464                                            Beloved
# 0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# 1879384493  If I'd Known Then What I Know Now: Why Not Lea...
# 0061076031                 Mary-Kate & Ashley Switching Goals
# 0439095026                       Tell Me This Isn't Happening
# 0689821166                            Flood: Mississippi 1927
# 0971880107                                        Wild Animus
# 0345402871                                           Airframe
# 0345417623                                           Timeline
# 0684823802                           Out of the Silent Planet
# ...                                                       ...
# 1853260053                          Tess of the d"Urbervilles
# 1414035004  The Adventures of Drew and Ellie: The Magical ...
# 0060938412                     The Accidental Virgin: A Novel
# 0140067477                                    The Tao of Pooh
# 0345465083                                         Seabiscuit
# 0451625889                                         The Prince
# 1558531025                     Life's Little Instruction Book
# 0441783589                                  Starship Troopers
# 0394895894    The Ruby in the Smoke: A Sally Lockhart Mystery
# 1569871213                                       Black Beauty
# 0375410538                                       Anil's Ghost
# 0966986105                            Prescription for Terror
# 087113375X  Modern Manners: An Etiquette Book for Rude People
# 0340767936                                     Turning Thirty
# 0743403843                                           Decipher
# 0060930365  My First Cousin Once Removed: Money, Madness, ...
# 0060177586          Standing Firm: A Vice-Presidential Memoir
# 0071416331  Team Bush: Leadership Lessons from the Bush Wh...
# 0375509038  The Right Man: The Surprise Presidency of Geor...
# 0553062042     The Daybreakers (The Louis L'Amour Collection)
# 0316769487                             The Catcher in the rye
# 8445071408   El Senor De Los Anillos: LA Comunidad Del Anillo
# 8445071769  El Senor De Los Anillos / the Lord of the Ring...
# 8445071777        El Senor De Los Anillos: El Retorno Del Rey
# 0679429220            Midnight in the Garden of Good and Evil
# 0671867156                          Pretend You Don't See Her
# 0312252617                                         Fast Women
# 0312261594                                Female Intelligence
# 0316748641      Pasquale's Nose: Idle Days in an Italian Town
# 0316973742                       The Gospel of Judas: A Novel
#
#                                                      Category  \
# ISBN
# 0195153448  Livres anglais et étrangers > Literature & Fic...
# 0002005018  Livres anglais et étrangers > Literature & Fic...
# 0060973129     Livres anglais et étrangers > History > Europe
# 0374157065  Livres anglais et étrangers > Science > Biolog...
# 0393045218  Livres anglais et étrangers > Arts & Photograp...
# 0399135782  Livres anglais et étrangers > Literature & Fic...
# 0425176428  Livres anglais et étrangers > History > Histor...
# 0671870432  Livres anglais et étrangers > Literature & Fic...
# 0679425608  Livres anglais et étrangers > Literature & Fic...
# 074322678X  Livres anglais et étrangers > Literature & Fic...
# 0771074670  Livres anglais et étrangers > Literature & Fic...
# 080652121X     Livres anglais et étrangers > History > Europe
# 0887841740  Livres anglais et étrangers > Literature & Fic...
# 1552041778  Livres anglais et étrangers > Literature & Fic...
# 1558746218  Livres anglais et étrangers > Religion & Spiri...
# 1567407781  Livres anglais et étrangers > Mystery & Thrill...
# 1575663937  Livres anglais et étrangers > Science > Biolog...
# 1881320189  Livres anglais et étrangers > Literature & Fic...
# 0440234743  Livres anglais et étrangers > Mystery & Thrill...
# 0452264464  Livres anglais et étrangers > Literature & Fic...
# 0609804618  Livres anglais et étrangers > Entertainment > ...
# 1841721522  Livres anglais et étrangers > Cooking, Food & ...
# 1879384493  Livres anglais et étrangers > Health, Mind & B...
# 0061076031  Livres anglais et étrangers > Children's Books...
# 0439095026  Livres anglais et étrangers > Children's Books...
# 0689821166  Livres anglais et étrangers > Children's Books...
# 0971880107  Livres anglais et étrangers > Literature & Fic...
# 0345402871  Livres anglais et étrangers > Literature & Fic...
# 0345417623  Livres anglais et étrangers > Mystery & Thrill...
# 0684823802  Livres anglais et étrangers > Science Fiction ...
# ...                                                       ...
# 1853260053  Livres anglais et étrangers > Literature & Fic...
# 1414035004  Livres anglais et étrangers > Children's Books...
# 0060938412  Livres anglais et étrangers > Boutiques > Cher...
# 0140067477  Livres anglais et étrangers > Entertainment > ...
# 0345465083   Livres anglais et étrangers > History > Americas
# 0451625889  Livres anglais et étrangers > Nonfiction > Pol...
# 1558531025  Livres anglais et étrangers > Religion & Spiri...
# 0441783589  Livres anglais et étrangers > Science Fiction ...
# 0394895894  Livres anglais et étrangers > Children's Books...
# 1569871213                                                NaN
# 0375410538  Livres anglais et étrangers > Literature & Fic...
# 0966986105  Livres anglais et étrangers > Mystery & Thrill...
# 087113375X  Livres anglais et étrangers > Entertainment > ...
# 0340767936  Livres anglais et étrangers > Literature & Fic...
# 0743403843  Livres anglais et étrangers > Mystery & Thrill...
# 0060930365  Livres anglais et étrangers > Biographies & Me...
# 0060177586  Livres anglais et étrangers > Biographies & Me...
# 0071416331  Livres anglais et étrangers > Business & Inves...
# 0375509038  Livres anglais et étrangers > Nonfiction > Pol...
# 0553062042  Livres anglais et étrangers > Literature & Fic...
# 0316769487  Livres anglais et étrangers > Literature & Fic...
# 8445071408  Livres anglais et étrangers > Literature & Fic...
# 8445071769  Livres anglais et étrangers > Literature & Fic...
# 8445071777  Livres anglais et étrangers > Literature & Fic...
# 0679429220   Livres anglais et étrangers > History > Americas
# 0671867156  Livres anglais et étrangers > Mystery & Thrill...
# 0312252617  Livres anglais et étrangers > Mystery & Thrill...
# 0312261594  Livres anglais et étrangers > Literature & Fic...
# 0316748641     Livres anglais et étrangers > History > Europe
# 0316973742  Livres anglais et étrangers > Mystery & Thrill...
#
#                                                        Author  Language Pages  \
# ISBN
# 0195153448            Mark P. O. Morford , Robert J. Lenardon   Anglais  1028
# 0002005018                                  Richard B. Wright   Anglais   432
# 0060973129                                       Carlo D'Este   Anglais   576
# 0374157065                                   Gina Bari Kolata   Anglais   330
# 0393045218         Elizabeth Wayland Barber , E. J. W. Barber   Anglais   240
# 0399135782                                            Amy Tan   Anglais   415
# 0425176428                                      Robert Cowley   Anglais   416
# 0671870432                          Scott Turow , Stacy Keach   Anglais   483
# 0679425608                           David Cordingly , Godoff   Anglais   296
# 074322678X                                            Beattie   Anglais   208
# 0771074670                               David Adams Richards   Anglais   232
# 080652121X                                      LEBOR , Lebor   Anglais   293
# 0887841740                                        Sheila Heti   Anglais   150
# 1552041778                                       J. R. Kaiser   Anglais   442
# 1558746218  Jack Canfield , Mark Victor Hansen , Jennifer ...   Anglais   328
# 1567407781                            Author Loren D Estleman   Anglais   306
# 1575663937                                 Robert Hendrickson   Anglais   288
# 1881320189                                       Julia Oliver   Anglais   192
# 0440234743                                       John Grisham   Anglais   544
# 0452264464                                      Toni Morrison   Anglais   288
# 0609804618                        Onion Staff , Scott Dikkers   Anglais   176
# 1841721522    Celia Brooks Brown , Jane Noraika , Philip Webb   Anglais     5
# 1879384493                                        J R Parrish   Anglais   136
# 0061076031                           Mary-Kate & Ashley Olsen   Anglais   128
# 0439095026                  Robynn Clairday , Robynn Clareday   Anglais   144
# 0689821166                      Kathleen Duey , Karen A. Bale   Anglais   176
# 0971880107                                       Rich Shapero   Anglais   328
# 0345402871                                   Michael Crichton   Anglais   448
# 0345417623                                   Michael Crichton   Anglais   516
# 0684823802                                        C. S. Lewis   Anglais   160
# ...                                                       ...       ...   ...
# 1853260053                                       Thomas Hardy   Anglais   357
# 1414035004                                     Charles Noland   Anglais    80
# 0060938412                                    Valerie Frankel   Anglais   288
# 0140067477                                      Benjamin Hoff   Anglais   176
# 0345465083                                  Laura Hillenbrand   Anglais   480
# 0451625889                                Niccolo Machiavelli   Anglais    61
# 1558531025                                   Jackson H. Brown   Anglais   315
# 0441783589                                 Robert A. Heinlein   Anglais   352
# 0394895894                                     Philip Pullman   Anglais   240
# 1569871213                                        Anna Sewell             NaN
# 0375410538                                   Michael Ondaatje   Anglais   320
# 0966986105                                  Sandra Levy Ceren   Anglais   237
# 087113375X                                     P. J. O'Rourke   Anglais   280
# 0340767936                                         Mike Gayle   Anglais   384
# 0743403843                                        Stel Pavlou   Anglais   816
# 0060930365                                 Sarah Payne Stuart   Anglais   256
# 0060177586                                         Dan Quayle   Anglais   402
# 0071416331                                    Donald F. Kettl   Anglais   224
# 0375509038                                         David Frum   Anglais   320
# 0553062042                                      Louis L'amour   Anglais   224
# 0316769487                                     J. D. Salinger   Anglais   240
# 8445071408                                     J.R.R. TOLKIEN  Espagnol   560
# 8445071769                                     J.R.R. TOLKIEN  Espagnol   464
# 8445071777                                     J.R.R. TOLKIEN  Espagnol   416
# 0679429220                                       John Berendt   Anglais   400
# 0671867156                                 Mary Higgins Clark   Anglais   320
# 0312252617                                    Jennifer Crusie   Anglais   358
# 0312261594                                        Jane Heller   Anglais   336
# 0316748641                                       Michael Rips   Anglais   224
# 0316973742                                        Simon Mawer   Anglais   368
#
#                       Dimensions
# ISBN
# 0195153448  23,2 x 3,1 x 18,9 cm
# 0002005018  15,5 x 2,8 x 28,2 cm
# 0060973129    3 x 13,5 x 20,1 cm
# 0374157065  12,7 x 1,9 x 22,2 cm
# 0393045218    19 x 2,5 x 24,8 cm
# 0399135782    23,7 x 3,7 x 16 cm
# 0425176428  15,2 x 2,3 x 22,9 cm
# 0671870432  10,2 x 2,9 x 17,8 cm
# 0679425608  16,5 x 2,5 x 24,1 cm
# 074322678X  13,3 x 1,1 x 20,5 cm
# 0771074670  13,7 x 1,4 x 21,2 cm
# 080652121X  15,2 x 2,5 x 22,2 cm
# 0887841740    14 x 1,9 x 20,3 cm
# 1552041778  10,8 x 1,9 x 17,8 cm
# 1558746218  15,2 x 3,2 x 22,9 cm
# 1567407781  10,8 x 1,3 x 18,4 cm
# 1575663937  15,2 x 1,9 x 23,5 cm
# 1881320189  14,6 x 2,5 x 22,9 cm
# 0440234743    10,4 x 3 x 17,5 cm
# 0452264464  13,9 x 1,7 x 20,3 cm
# 0609804618    21,6 x 1 x 28,2 cm
# 1841721522  23,5 x 2,5 x 24,1 cm
# 1879384493  14,7 x 1,2 x 21,4 cm
# 0061076031    10,8 x 1,3 x 19 cm
# 0439095026  10,8 x 1,3 x 17,1 cm
# 0689821166      13 x 1 x 19,4 cm
# 0971880107  17,1 x 3,2 x 24,1 cm
# 0345402871    10,7 x 3 x 17,5 cm
# 0345417623  10,6 x 2,8 x 17,4 cm
# 0684823802  10,8 x 1,3 x 17,8 cm
# ...                          ...
# 1853260053    12,7 x 2 x 19,9 cm
# 1414035004  22,9 x 15,2 x 0,5 cm
# 0060938412  13,5 x 1,7 x 20,3 cm
# 0140067477    13 x 1,2 x 18,4 cm
# 0345465083  10,6 x 2,6 x 17,5 cm
# 0451625889  17,8 x 2,5 x 12,7 cm
# 1558531025  1,3 x 15,2 x 11,4 cm
# 0441783589  10,8 x 2,2 x 19,2 cm
# 0394895894  10,7 x 1,7 x 17,5 cm
# 1569871213
# 0375410538  15,9 x 3,2 x 22,9 cm
# 0966986105  14,6 x 1,9 x 22,2 cm
# 087113375X    14 x 2,1 x 20,9 cm
# 0340767936    15,4 x 23,3 x 3 cm
# 0743403843  11,1 x 0,2 x 17,8 cm
# 0060930365  13,5 x 1,4 x 20,3 cm
# 0060177586  16,5 x 4,4 x 24,1 cm
# 0071416331  14,5 x 2,3 x 21,6 cm
# 0375509038  16,3 x 3,4 x 24,4 cm
# 0553062042  22,9 x 15,7 x 2,3 cm
# 0316769487  10,8 x 1,9 x 17,1 cm
# 8445071408  3,2 x 11,4 x 17,1 cm
# 8445071769  11,4 x 2,5 x 17,1 cm
# 8445071777  18,1 x 11,7 x 2,2 cm
# 0679429220  14,7 x 3,3 x 24,3 cm
# 0671867156  10,6 x 1,8 x 17,1 cm
# 0312252617  16,5 x 2,9 x 24,1 cm
# 0312261594  15,8 x 3,3 x 24,4 cm
# 0316748641  12,7 x 1,5 x 20,3 cm
# 0316973742  13,3 x 1,9 x 20,3 cm
#
# [100 rows x 7 columns]

# %% [markdown]
# ###  <a id='ILaNA'></a> <div style="font-size:120%;  margin-left: 25px;"> <span class="label label-success">Checking the result (missing information)</span></div>

# %%
books.isna().sum()
# Out:
# Year-Of-Publication    0
# Name                   0
# Category               4
# Author                 0
# Language               0
# Pages                  7
# Dimensions             0
# dtype: int64

# %% [markdown]
# ## <a id='II'></a><h2 style="text-align=center; font-size=220">  <span class="label label-info" style="text-align=center;"> II Scrapping BookFinder.com to get descriptions about books to be used for content based recommendation</span>  </h2>

# %% [markdown]
# ## Getting Book description from the website bookfinder.com

# %%
from selenium import webdriver
from bs4 import BeautifulSoup


# instantiate a chrome options object so you can set the size and headless preference
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--window-size=1920x1080")

# Chrome without pictures for reduced loading time
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.managed_default_content_settings.images": 2}
chrome_options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=CHROME_PATH)

isbns = list(books.index):
descriptions = []
for isbn in isbns:
    
    driver.get("https://www.bookfinder.com/isbn_search/")

    driver.implicitly_wait(3)

    driver.find_element_by_xpath("""//*[@name="isbn"]""").send_keys(isbn)
    driver.find_element_by_xpath("""//*[@id="submitBtn"]""").click()

    driver.implicitly_wait(3)

    content = driver.find_element_by_xpath("""//*[@id="bookSummary"]""")
    data = BeautifulSoup(content.get_attribute('innerHTML'), "lxml")
    
    descriptions.append(data.text)

# %%
books['Description'] = descriptions

# %% [markdown]
# <div class='alert alert-info'>
# This was just a demonstration. The process takes a lot of time, depending on the internet connection speed and the processing power of the computer. We can launch more than one navigator to scrap more than one page at once.</div>

# %% [markdown]
# ## <a id='III'></a><h2 style="text-align=center; font-size=220">  <span class="label label-info" style="text-align=center;"> III Measuring the similarity between two books based by using the cosine distance between their Description</span>  </h2>

# %% [markdown]
# This can be a way to perform content based recommandation: we can suggest to the end user the k books whose descriptions are the most similar to that of the book chosen by the user.

# %%
import re, math
from collections import Counter


WORD = re.compile(r'\w+')


def get_cosine(vec1, vec2):
    
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)


Harry_potter_1 = """It was always difficult being Harry Potter and it isn't much easier now that he is an overworked employee of the Ministry of Magic, a husband, and father of three school-age children.
While Harry grapples with a past that refuses to stay where it belongs, his youngest son Albus must struggle with the weight of a family legacy he never wanted. As past and present fuse ominously, both father and son learn the uncomfortable truth: sometimes, darkness comes from unexpected places.

The playscript for Harry Potter and the Cursed Child was originally released as a 'special rehearsal edition' alongside the opening of Jack Thorne's play in London's West End in summer 2016. Based on an original story by J.K. Rowling, John Tiffany and Jack Thorne, the play opened to rapturous reviews from theatregoers and critics alike, while the official playscript became an immediate global bestseller.

This revised paperback edition updates the 'special rehearsal edition' with the conclusive and final dialogue from the play, which has subtly changed since its rehearsals, as well as a conversation piece between director John Tiffany and writer Jack Thorne, who share stories and insights about reading playscripts. This edition also includes useful background information including the Potter family tree and a timeline of events from the Wizarding World prior to the beginning of Harry Potter and the Cursed Child."""


Harry_potter_2 = """Harry Potter has never even heard of Hogwarts when the letters start dropping on the doormat at number four, Privet Drive. Addressed in green ink on yellowish parchment with a purple seal, they are swiftly confiscated by his grisly aunt and uncle. Then, on Harry's eleventh birthday, a great beetle-eyed giant of a man called Rubeus Hagrid bursts in with some astonishing news: Harry Potter is a wizard, and he has a place at Hogwarts School of Witchcraft and Wizardry. An incredible adventure is about to begin! These new editions of the classic and internationally bestselling, multi-award-winning series feature instantly pick-up-able new jackets by Jonny Duddle, with huge child appeal, to bring Harry Potter to the next generation of readers. It's time to pass the magic on"""


Star_wars = """A Jedi must be a fearless warrior, a guardian of justice, and a scholar in the ways of the Force. But perhaps a Jedi’s most essential duty is to pass on what they have learned. Master Yoda trained Dooku; Dooku trained Qui-Gon Jinn; and now Qui-Gon has a Padawan of his own. But while Qui-Gon has faced all manner of threats and danger as a Jedi, nothing has ever scared him like the thought of failing his apprentice."""



vector1 = text_to_vector(Harry_potter_1)
vector2 = text_to_vector(Harry_potter_2)

vector3 = text_to_vector(Star_wars)

cosine1 = get_cosine(vector1, vector2)
cosine2 = get_cosine(vector2, vector3)

print ('Cosine distance between Harry Potter 1 and Harry Potter 2 reviews is:', cosine1)
print ('Cosine distance between Harry Potter 1 and Star wars reviews is:', cosine2)
# Out:
# Cosine distance between Harry Potter 1 and Harry Potter 2 reviews is: 0.5723332526830462
# Cosine distance between Harry Potter 1 and Star wars reviews is: 0.48625899626414265

# %% [markdown]
# <div class='alert alert-info'>
# This measured distance can be used later for Item-Item recommandation: REcommanding books based on the history of books that the user has already read</div>
